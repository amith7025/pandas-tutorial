# %%
 import pandas as pd

# %%
df = pd.read_csv('Housing.csv')
df.head(100)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420         4          2        3      yes        no       no
# 1   12250000  8960         4          4        4      yes        no       no
# 2   12250000  9960         3          2        2      yes        no      yes
# 3   12215000  7500         4          2        2      yes        no      yes
# 4   11410000  7420         4          1        2      yes       yes      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 95   6300000  4100         3          2        3      yes        no       no
# 96   6300000  9000         3          1        1      yes        no      yes
# 97   6300000  6400         3          1        1      yes       yes      yes
# 98   6293000  6600         3          2        3      yes        no       no
# 99   6265000  6000         4          1        3      yes       yes      yes
#
# ...

# %%
tempdict = {'col1':[1,2,3],'col2':[4,5,6],'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
dfl = pd.DataFrame({'name':['abc','cdf']})
dfl.head()
# Out:
#   name
# 0  abc
# 1  cdf

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishing status
# 540              no              no        2       no       unfurnished
# 541              no              no        0       no    semi-furnished
# 542              no              no        0       no       unfurnished
# 543              no              no        0       no         furnished
# 544              no              no        0       no       unfurnished

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishing status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# price                 int64
# area                  int64
# bedrooms              int64
# bathrooms             int64
# stories               int64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking               int64
# prefarea             object
# furnishing status    object
# dtype: object

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.describe(include='object')
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishing status
# count                545
# unique                 3
# top       semi-furnished
# freq                 227

# %%
df.area
# Out:
# 0      7420
# 1      8960
# 2      9960
# 3      7500
# 4      7420
#        ...
# 540    3000
# 541    2400
# 542    3620
# 543    2910
# 544    3850
# Name: area, Length: 545, dtype: int64

# %%
df['area'] == 9960
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Name: area, Length: 545, dtype: bool

# %%
df[['area','parking']]
# Out:
#      area  parking
# 0    7420        2
# 1    8960        3
# 2    9960        2
# 3    7500        3
# 4    7420        2
# ..    ...      ...
# 540  3000        2
# 541  2400        0
# 542  3620        0
# 543  2910        0
# 544  3850        0
#
# [545 rows x 2 columns]

# %%
df['furnishing status']
# Out:
# 0           furnished
# 1           furnished
# 2      semi-furnished
# 3           furnished
# 4           furnished
#             ...
# 540       unfurnished
# 541    semi-furnished
# 542       unfurnished
# 543         furnished
# 544       unfurnished
# Name: furnishing status, Length: 545, dtype: object

# %%
df.area.unique()
# Out:
# array([ 7420,  8960,  9960,  7500,  8580, 16200,  8100,  5750, 13200,
#         6000,  6550,  3500,  7800,  6600,  8500,  4600,  6420,  4320,
#         7155,  8050,  4560,  8800,  6540,  8875,  7950,  5500,  7475,
#         7000,  4880,  5960,  6840,  7482,  9000,  6360,  6480,  4300,
#         7440,  6325,  5150, 11440,  7680,  8880,  6240, 11175,  7700,
#        12090,  4000,  5020,  4040,  4260,  6500,  5700, 10500,  3760,
#         8250,  6670,  3960,  7410,  5000,  6750,  4800,  7200,  4100,
#         6400,  6350,  4500,  5450,  3240,  6615,  8372,  9620,  6800,
#         8000,  6900,  3700,  7020,  7231,  6254,  7320,  6525, 15600,
#         7160, 11460,  5828,  5200,  5400,  4640,  5800,  6660,  4700,
#         5136,  4400,  3300,  3650,  6100,  2817,  7980,  3150,  6210,
#         6825,  6710,  6450, 10269,  8400,  5300,  3800,  9800,  8520,
#         6050,  7085,  3180,  3410,  3000, 11410,  5720,  3540,  7600,
# ...

# %%
df[(df['furnishing status'] == 'furnished') & (df['basement'] == 'no')]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 13    9240000  3500         4          2        2      yes        no       no
# 17    8960000  8500         3          2        4      yes        no       no
# 18    8890000  4600         3          2        2      yes       yes       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 493   2800000  3960         3          1        1      yes        no       no
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
df.iloc[19]
# Out:
# price                       8855000
# area                           6420
# bedrooms                          3
# bathrooms                         2
# stories                           2
# mainroad                        yes
# guestroom                        no
# basement                         no
# hotwaterheating                  no
# airconditioning                 yes
# parking                           1
# prefarea                        yes
# furnishing status    semi-furnished
# Name: 19, dtype: object

# %%
df.iloc[19,3]
# Out:
# 2

# %%
df.iloc[1:100]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 1   12250000  8960         4          4        4      yes        no       no
# 2   12250000  9960         3          2        2      yes        no      yes
# 3   12215000  7500         4          2        2      yes        no      yes
# 4   11410000  7420         4          1        2      yes       yes      yes
# 5   10850000  7500         3          3        1      yes        no      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 95   6300000  4100         3          2        3      yes        no       no
# 96   6300000  9000         3          1        1      yes        no      yes
# 97   6300000  6400         3          1        1      yes       yes      yes
# 98   6293000  6600         3          2        3      yes        no       no
# 99   6265000  6000         4          1        3      yes       yes      yes
#
# ...

# %%
duplicate = df.copy()
duplicate.set_index('price',inplace=True)
duplicate.head()
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 13300000  7420         4          2        3      yes        no       no
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
# 12215000  7500         4          2        2      yes        no      yes
# 11410000  7420         4          1        2      yes       yes      yes
#
#          hotwaterheating airconditioning  parking prefarea furnishing status
# price
# 13300000              no             yes        2      yes         furnished
# 12250000              no             yes        3       no         furnished
# 12250000              no              no        2      yes    semi-furnished
# 12215000              no             yes        3      yes         furnished
# 11410000              no             yes        2       no         furnished

# %%
duplicate.loc[13300000]
# Out:
# area                      7420
# bedrooms                     4
# bathrooms                    2
# stories                      3
# mainroad                   yes
# guestroom                   no
# basement                    no
# hotwaterheating             no
# airconditioning            yes
# parking                      2
# prefarea                   yes
# furnishing status    furnished
# Name: 13300000, dtype: object

# %%
df.isnull().sum()
# Out:
# price                0
# area                 0
# bedrooms             0
# bathrooms            0
# stories              0
# mainroad             0
# guestroom            0
# basement             0
# hotwaterheating      0
# airconditioning      0
# parking              0
# prefarea             0
# furnishing status    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.drop('mainroad',axis=1)
# Out:
#         price  area  bedrooms  bathrooms  stories guestroom basement  \
# 0    13300000  7420         4          2        3        no       no
# 1    12250000  8960         4          4        4        no       no
# 2    12250000  9960         3          2        2        no      yes
# 3    12215000  7500         4          2        2        no      yes
# 4    11410000  7420         4          1        2       yes      yes
# ..        ...   ...       ...        ...      ...       ...      ...
# 540   1820000  3000         2          1        1        no      yes
# 541   1767150  2400         3          1        1        no       no
# 542   1750000  3620         2          1        1        no       no
# 543   1750000  2910         3          1        1        no       no
# 544   1750000  3850         3          1        2        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishing status
# ...

# %%
df['bedrooms'] = 100
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       100          2        3      yes        no       no
# 1  12250000  8960       100          4        4      yes        no       no
# 2  12250000  9960       100          2        2      yes        no      yes
# 3  12215000  7500       100          2        2      yes        no      yes
# 4  11410000  7420       100          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishing status
# 0              no             yes        2      yes         furnished
# 1              no             yes        3       no         furnished
# 2              no              no        2      yes    semi-furnished
# 3              no             yes        3      yes         furnished
# 4              no             yes        2       no         furnished

# %%
df.iloc[0,-1] = 0
df.head(545)
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       100          2        3      yes        no       no
# 1    12250000  8960       100          4        4      yes        no       no
# 2    12250000  9960       100          2        2      yes        no      yes
# 3    12215000  7500       100          2        2      yes        no      yes
# 4    11410000  7420       100          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       100          1        1      yes        no      yes
# 541   1767150  2400       100          1        1       no        no       no
# 542   1750000  3620       100          1        1      yes        no       no
# 543   1750000  2910       100          1        1       no        no       no
# 544   1750000  3850       100          1        2      yes        no       no
#
# ...

# %%
df['new airconditionig'] = df['airconditioning'].apply(lambda x:1 if x=='yes' else 0)
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       100          2        3      yes        no       no
# 1  12250000  8960       100          4        4      yes        no       no
# 2  12250000  9960       100          2        2      yes        no      yes
# 3  12215000  7500       100          2        2      yes        no      yes
# 4  11410000  7420       100          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishing status  \
# 0              no             yes        2      yes                 0
# 1              no             yes        3       no         furnished
# 2              no              no        2      yes    semi-furnished
# 3              no             yes        3      yes         furnished
# 4              no             yes        2       no         furnished
#
#    new airconditionig
# 0                   1
# 1                   1
# ...

# %%
df[df['airconditioning']== 'yes'].head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       100          2        3      yes        no       no
# 1  12250000  8960       100          4        4      yes        no       no
# 3  12215000  7500       100          2        2      yes        no      yes
# 4  11410000  7420       100          1        2      yes       yes      yes
# 5  10850000  7500       100          3        1      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishing status  \
# 0              no             yes        2      yes                 0
# 1              no             yes        3       no         furnished
# 3              no             yes        3      yes         furnished
# 4              no             yes        2       no         furnished
# 5              no             yes        2      yes    semi-furnished
#
#    new airconditionig
# 0                   1
# 1                   1
# ...

# %%
df = df.apply(lambda x:1 if x=='yes' else 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9576\470422522.py in ?()
# ----> 1 df = df.apply(lambda x:1 if x=='yes' else 0)
#
# ~\Envs\workshop\Lib\site-packages\pandas\core\frame.py in ?(self, func, axis, raw, result_type, args, **kwargs)
#    9419             result_type=result_type,
#    9420             args=args,
#    9421             kwargs=kwargs,
#    9422         )
# -> 9423         return op.apply().__finalize__(self, method="apply")
#
# ~\Envs\workshop\Lib\site-packages\pandas\core\apply.py in ?(self)
#     674         # raw
#     675         elif self.raw:
#     676             return self.apply_raw()
#     677
# --> 678         return self.apply_standard()
#
# ~\Envs\workshop\Lib\site-packages\pandas\core\apply.py in ?(self)
#     797     def apply_standard(self):
# ...

# %%
# Define a function to update values
def update_value(x):
    return x * 2  # For example, doubling each value

# Apply the function to all values
df_updated = df.applymap(update_value)

# %%
df_updated.head()
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  26600000  14840       200          4        6   yesyes      nono     nono
# 1  24500000  17920       200          8        8   yesyes      nono     nono
# 2  24500000  19920       200          4        4   yesyes      nono   yesyes
# 3  24430000  15000       200          4        4   yesyes      nono   yesyes
# 4  22820000  14840       200          2        4   yesyes    yesyes   yesyes
#
#   hotwaterheating airconditioning  parking prefarea  \
# 0            nono          yesyes        4   yesyes
# 1            nono          yesyes        6     nono
# 2            nono            nono        4   yesyes
# 3            nono          yesyes        6   yesyes
# 4            nono          yesyes        4     nono
#
#               furnishing status  new airconditionig
# 0                             0                   2
# 1            furnishedfurnished                   2
# ...

# %%
df.to_csv('output.csv')

# %%
df.to_json()
# Out:
# '{"price":{"0":13300000,"1":12250000,"2":12250000,"3":12215000,"4":11410000,"5":10850000,"6":10150000,"7":10150000,"8":9870000,"9":9800000,"10":9800000,"11":9681000,"12":9310000,"13":9240000,"14":9240000,"15":9100000,"16":9100000,"17":8960000,"18":8890000,"19":8855000,"20":8750000,"21":8680000,"22":8645000,"23":8645000,"24":8575000,"25":8540000,"26":8463000,"27":8400000,"28":8400000,"29":8400000,"30":8400000,"31":8400000,"32":8295000,"33":8190000,"34":8120000,"35":8080940,"36":8043000,"37":7980000,"38":7962500,"39":7910000,"40":7875000,"41":7840000,"42":7700000,"43":7700000,"44":7560000,"45":7560000,"46":7525000,"47":7490000,"48":7455000,"49":7420000,"50":7420000,"51":7420000,"52":7350000,"53":7350000,"54":7350000,"55":7350000,"56":7343000,"57":7245000,"58":7210000,"59":7210000,"60":7140000,"61":7070000,"62":7070000,"63":7035000,"64":7000000,"65":6930000,"66":6930000,"67":6895000,"68":6860000,"69":6790000,"70":6790000,"71":6755000,"72":6720000,"73":6685000,"74":6650000,"75":6650000,"
# ...

# %%
df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>price</th>\n      <th>area</th>\n      <th>bedrooms</th>\n      <th>bathrooms</th>\n      <th>stories</th>\n      <th>mainroad</th>\n      <th>guestroom</th>\n      <th>basement</th>\n      <th>hotwaterheating</th>\n      <th>airconditioning</th>\n      <th>parking</th>\n      <th>prefarea</th>\n      <th>furnishing status</th>\n      <th>new airconditionig</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>13300000</td>\n      <td>7420</td>\n      <td>100</td>\n      <td>2</td>\n      <td>3</td>\n      <td>yes</td>\n      <td>no</td>\n      <td>no</td>\n      <td>no</td>\n      <td>yes</td>\n      <td>2</td>\n      <td>yes</td>\n      <td>0</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>12250000</td>\n      <td>8960</td>\n      <td>100</td>\n      <td>4</td>\n      <td>4</td>\n      <td>yes</td>\n      <td>no</td>\n   
# ...

# %%
del df

# %%
import pandas as pd
import missingno as msno

# %%
stats_df = pd.read_csv('Seasons_Stats.csv')
stats_df.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
df = stats_df.loc[stats_df['Year'] == 2017]

# %%
df
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 24096       24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0
# 24097       24097  2017.0         Quincy Acy  PF  26.0  TOT  38.0   1.0
# 24098       24098  2017.0         Quincy Acy  PF  26.0  DAL   6.0   0.0
# 24099       24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0
# 24100       24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0
# ...           ...     ...                ...  ..   ...  ...   ...   ...
# 24686       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0
# 24687       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0
# 24688       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0
# 24689       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0
# 24690       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB   AST   STL   BLK    TOV  \
# ...

# %%
stats_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24691 entries, 0 to 24690
# Data columns (total 53 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  24691 non-null  int64
#  1   Year        24624 non-null  float64
#  2   Player      24624 non-null  object
#  3   Pos         24624 non-null  object
#  4   Age         24616 non-null  float64
#  5   Tm          24624 non-null  object
#  6   G           24624 non-null  float64
#  7   GS          18233 non-null  float64
#  8   MP          24138 non-null  float64
#  9   PER         24101 non-null  float64
#  10  TS%         24538 non-null  float64
#  11  3PAr        18839 non-null  float64
#  12  FTr         24525 non-null  float64
#  13  ORB%        20792 non-null  float64
#  14  DRB%        20792 non-null  float64
#  15  TRB%        21571 non-null  float64
#  16  AST%        22555 non-null  float64
#  17  STL%        20792 non-null  float64
# ...

# %%
msno.bar(stats_df)
# Out:
# <Axes: >

# %%
player_df = pd.read_csv('player_data.csv')
player_df.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
msno.bar(player_df)
# Out:
# <Axes: >

# %%
merge_df = df.merge(player_df,how='left',left_on='Player',right_on='name')

# %%
merge_df
# Out:
#      Unnamed: 0    Year             Player Pos   Age   Tm     G    GS      MP  \
# 0         24096  2017.0       Alex Abrines  SG  23.0  OKC  68.0   6.0  1055.0
# 1         24097  2017.0         Quincy Acy  PF  26.0  TOT  38.0   1.0   558.0
# 2         24098  2017.0         Quincy Acy  PF  26.0  DAL   6.0   0.0    48.0
# 3         24099  2017.0         Quincy Acy  PF  26.0  BRK  32.0   1.0   510.0
# 4         24100  2017.0       Steven Adams   C  23.0  OKC  80.0  80.0  2389.0
# ..          ...     ...                ...  ..   ...  ...   ...   ...     ...
# 600       24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0
# 601       24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0
# 602       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0
# 603       24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0
# 604       24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0
#
# ...

# %%
merge_df.head(1).T
# Out:
#                          0
# Unnamed: 0           24096
# Year                2017.0
# Player        Alex Abrines
# Pos                     SG
# Age                   23.0
# ...                    ...
# position               G-F
# height                 6-6
# weight               190.0
# birth_date  August 1, 1993
# college                NaN
#
# [61 rows x 1 columns]

# %%
merge_df['name'].isna().any()
# Out:
# True

# %%
merge_df['Player'].value_counts().sum()
# Out:
# 605

# %%
df['Player'].value_counts().sum()
# Out:
# 595

# %%
player_df['name'].value_counts().sum()
# Out:
# 4550

# %%
merge_df.value_counts().sum()
# Out:
# 0

# %%
merge_df.loc[~(merge_df['Player'] == 'NAN') & (merge_df['name'] == 'NAN')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Player, Pos, Age, Tm, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, blanl, OWS, DWS, WS, WS/48, blank2, OBPM, DBPM, BPM, VORP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS, name, year_start, year_end, position, height, weight, birth_date, college]
# Index: []
#
# [0 rows x 61 columns]

# %%
merge_df['name'].isna().sum()
# Out:
# 4

# %%
merge_df.loc[merge_df['name'].isna()]
# Out:
#      Unnamed: 0    Year             Player Pos   Age   Tm     G    GS      MP  \
# 349       24439  2017.0           Luc Mbah  SF  30.0  LAC  80.0  76.0  1787.0
# 350       24440  2017.0      James Michael  PF  24.0  GSW  52.0   2.0   457.0
# 352       24442  2017.0  Sheldon McClellan  SG  24.0  WAS  30.0   3.0   287.0
# 593       24679  2017.0        Metta World  SF  37.0  LAL  25.0   2.0   160.0
#
#       PER  ...     PF    PTS  name  year_start  year_end  position  height  \
# 349  10.3  ...  122.0  484.0   NaN         NaN       NaN       NaN     NaN
# 350  13.0  ...   47.0  147.0   NaN         NaN       NaN       NaN     NaN
# 352  10.1  ...   17.0   90.0   NaN         NaN       NaN       NaN     NaN
# 593   6.2  ...   18.0   57.0   NaN         NaN       NaN       NaN     NaN
#
#      weight  birth_date  college
# 349     NaN         NaN      NaN
# 350     NaN         NaN      NaN
# 352     NaN         NaN      NaN
# 593     NaN         NaN      NaN
#
# [4 rows x 61 columns]

# %%
player_misses = list(merge_df.loc[merge_df['name'].isna(),'Player'].values)
player_misses
# Out:
# ['Luc Mbah', 'James Michael', 'Sheldon McClellan', 'Metta World']

# %%
player_df.loc[player_df['name'].str.contains('Mbah')]
# Out:
#                   name  year_start  year_end position height  weight  \
# 2595  Luc Mbah a Moute        2009      2018        F    6-8   230.0
#
#              birth_date                                college
# 2595  September 9, 1986  University of California, Los Angeles

# %%
player_df.loc[player_df['name'].str.contains(' Michael')]
# Out:
#                       name  year_start  year_end position height  weight  \
# 2597  James Michael McAdoo        2015      2018        F    6-9   230.0
#
#            birth_date                       college
# 2597  January 4, 1993  University of North Carolina

# %%
player_df.loc[player_df['name'].str.contains('Sheldon')]
# Out:
#              name  year_start  year_end position height  weight  \
# 2475  Sheldon Mac        2017      2017        G    6-5   200.0
#
#              birth_date              college
# 2475  December 21, 1992  University of Miami

# %%
player_df.loc[player_df['name'].str.lower().str.contains('metta')]
# Out:
#                    name  year_start  year_end position height  weight  \
# 4487  Metta World Peace        2000      2017        F    6-6   260.0
#
#              birth_date                college
# 4487  November 13, 1979  St. John's University

# %%
player_df.head()
# Out:
#                   name  year_start  year_end position height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C   6-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F    6-9   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C    7-2   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G    6-1   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F    6-6   223.0
#
#          birth_date                                college
# 0     June 24, 1968                        Duke University
# 1     April 7, 1946                  Iowa State University
# 2    April 16, 1947  University of California, Los Angeles
# 3     March 9, 1969             Louisiana State University
# 4  November 3, 1974              San Jose State University

# %%
names_mapping = {
    'Luc Mbah a Moute':'Luc Mbah',
    'James Michael McAdoo':'James Michael',
    'Sheldon Mac':'Sheldon McClellan',
    'Metta World Peace':'Metta World'
}

# %%
for new_name,name_2017 in names_mapping.items():
    player_df.loc[player_df['name'] == new_name,'name'] = name_2017

# %%
merge_df['name'].isna().sum()
# Out:
# 4

# %%
merge_df.loc[merge_df['name'].isna()]
# Out:
#      Unnamed: 0    Year             Player Pos   Age   Tm     G    GS      MP  \
# 349       24439  2017.0           Luc Mbah  SF  30.0  LAC  80.0  76.0  1787.0
# 350       24440  2017.0      James Michael  PF  24.0  GSW  52.0   2.0   457.0
# 352       24442  2017.0  Sheldon McClellan  SG  24.0  WAS  30.0   3.0   287.0
# 593       24679  2017.0        Metta World  SF  37.0  LAL  25.0   2.0   160.0
#
#       PER  ...     PF    PTS  name  year_start  year_end  position  height  \
# 349  10.3  ...  122.0  484.0   NaN         NaN       NaN       NaN     NaN
# 350  13.0  ...   47.0  147.0   NaN         NaN       NaN       NaN     NaN
# 352  10.1  ...   17.0   90.0   NaN         NaN       NaN       NaN     NaN
# 593   6.2  ...   18.0   57.0   NaN         NaN       NaN       NaN     NaN
#
#      weight  birth_date  college
# 349     NaN         NaN      NaN
# 350     NaN         NaN      NaN
# 352     NaN         NaN      NaN
# 593     NaN         NaN      NaN
#
# [4 rows x 61 columns]

# %%
 player_df.loc[player_df['name'] == 'Luc Mbah a Moute']
# Out:
# Empty DataFrame
# Columns: [name, year_start, year_end, position, height, weight, birth_date, college]
# Index: []

# %%
df.loc[df['Player'] == 'Luc Mbah a Moute']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Year, Player, Pos, Age, Tm, G, GS, MP, PER, TS%, 3PAr, FTr, ORB%, DRB%, TRB%, AST%, STL%, BLK%, TOV%, USG%, blanl, OWS, DWS, WS, WS/48, blank2, OBPM, DBPM, BPM, VORP, FG, FGA, FG%, 3P, 3PA, 3P%, 2P, 2PA, 2P%, eFG%, FT, FTA, FT%, ORB, DRB, TRB, AST, STL, BLK, TOV, PF, PTS]
# Index: []
#
# [0 rows x 53 columns]

# %%
player_df.loc[player_df['name'] == 'Sheldon Mac']
# Out:
# Empty DataFrame
# Columns: [name, year_start, year_end, position, height, weight, birth_date, college]
# Index: []

# %%
columns_to_drop = ['G','GS','MP','PER']

# %%
merge_df.drop(columns=columns_to_drop,inplace=True)

# %%
merge_df
# Out:
#      Unnamed: 0    Year             Player Pos   Age   Tm    TS%   3PAr  \
# 0         24096  2017.0       Alex Abrines  SG  23.0  OKC  0.560  0.724
# 1         24097  2017.0         Quincy Acy  PF  26.0  TOT  0.565  0.529
# 2         24098  2017.0         Quincy Acy  PF  26.0  DAL  0.355  0.412
# 3         24099  2017.0         Quincy Acy  PF  26.0  BRK  0.587  0.542
# 4         24100  2017.0       Steven Adams   C  23.0  OKC  0.589  0.002
# ..          ...     ...                ...  ..   ...  ...    ...    ...
# 600       24686  2017.0        Cody Zeller  PF  24.0  CHO  0.604  0.002
# 601       24687  2017.0       Tyler Zeller   C  27.0  BOS  0.508  0.006
# 602       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  0.346  0.000
# 603       24689  2017.0        Paul Zipser  SF  22.0  CHI  0.503  0.448
# 604       24690  2017.0        Ivica Zubac   C  19.0  LAL  0.547  0.013
#
#        FTr  ORB%  ...     PF    PTS               name  year_start  year_end  \
# ...

# %%
team_mapping = {'OKC':'Oklahoma'}

# %%
merge_df['Team'] = merge_df['Tm'].replace(team_mapping)

# %%
merge_df
# Out:
#      Unnamed: 0    Year             Player Pos   Age   Tm    TS%   3PAr  \
# 0         24096  2017.0       Alex Abrines  SG  23.0  OKC  0.560  0.724
# 1         24097  2017.0         Quincy Acy  PF  26.0  TOT  0.565  0.529
# 2         24098  2017.0         Quincy Acy  PF  26.0  DAL  0.355  0.412
# 3         24099  2017.0         Quincy Acy  PF  26.0  BRK  0.587  0.542
# 4         24100  2017.0       Steven Adams   C  23.0  OKC  0.589  0.002
# ..          ...     ...                ...  ..   ...  ...    ...    ...
# 600       24686  2017.0        Cody Zeller  PF  24.0  CHO  0.604  0.002
# 601       24687  2017.0       Tyler Zeller   C  27.0  BOS  0.508  0.006
# 602       24688  2017.0  Stephen Zimmerman   C  20.0  ORL  0.346  0.000
# 603       24689  2017.0        Paul Zipser  SF  22.0  CHI  0.503  0.448
# 604       24690  2017.0        Ivica Zubac   C  19.0  LAL  0.547  0.013
#
#        FTr  ORB%  ...    PTS               name  year_start  year_end  \
# ...

# %%
merge_df['birth_date'] = pd.to_datetime(merge_df['birth_date'])

# %%
del merge_df['Unnamed: 0']

# %%
merge_df.head()
# Out:
#      Year        Player Pos   Age   Tm    TS%   3PAr    FTr  ORB%  DRB%  ...  \
# 0  2017.0  Alex Abrines  SG  23.0  OKC  0.560  0.724  0.144   1.9   7.1  ...
# 1  2017.0    Quincy Acy  PF  26.0  TOT  0.565  0.529  0.353   3.9  18.0  ...
# 2  2017.0    Quincy Acy  PF  26.0  DAL  0.355  0.412  0.176   4.6  15.2  ...
# 3  2017.0    Quincy Acy  PF  26.0  BRK  0.587  0.542  0.373   3.8  18.2  ...
# 4  2017.0  Steven Adams   C  23.0  OKC  0.589  0.002  0.392  13.0  15.5  ...
#
#      PTS          name  year_start  year_end  position  height  weight  \
# 0  406.0  Alex Abrines      2017.0    2018.0       G-F     6-6   190.0
# 1  222.0    Quincy Acy      2013.0    2018.0         F     6-7   240.0
# 2   13.0    Quincy Acy      2013.0    2018.0         F     6-7   240.0
# 3  209.0    Quincy Acy      2013.0    2018.0         F     6-7   240.0
# 4  905.0  Steven Adams      2014.0    2018.0         C     7-0   255.0
#
#    birth_date                   college      Team
# ...

# %%
merge_df.loc[merge_df['Player'].duplicated(keep=False),['Player','Tm','Team']].sort_values(by='Player')
# Out:
#                Player   Tm Team
# 58       Andrew Bogut  TOT  TOT
# 60       Andrew Bogut  CLE  CLE
# 59       Andrew Bogut  DAL  DAL
# 403  Andrew Nicholson  BRK  BRK
# 402  Andrew Nicholson  WAS  WAS
# ..                ...  ...  ...
# 492      Wayne Selden  TOT  TOT
# 494      Wayne Selden  MEM  MEM
# 166      Yogi Ferrell  TOT  TOT
# 167      Yogi Ferrell  BRK  BRK
# 168      Yogi Ferrell  DAL  DAL
#
# [179 rows x 3 columns]

# %%
copy = merge_df.copy()

# %%
merge_df.loc[merge_df['Tm'] == 'TOT'].index
# Out:
# Index([  1,  14,  32,  55,  58,  65,  70,  81,  90, 107, 110, 139, 140, 153,
#        156, 166, 176, 188, 193, 200, 226, 236, 239, 259, 263, 278, 294, 306,
#        314, 328, 355, 358, 361, 383, 401, 405, 411, 415, 435, 443, 446, 458,
#        476, 492, 509, 517, 527, 535, 539, 563, 574, 577, 580, 586],
#       dtype='int64')

# %%
merge_df.drop(merge_df.loc[merge_df['Tm'] == 'TOT'].index,inplace=True)

# %%
merge_df.iloc[14]
# Out:
# Year                          2017.0
# Player               Justin Anderson
# Pos                               SF
# Age                             23.0
# Tm                               PHI
# TS%                            0.564
# 3PAr                           0.444
# FTr                            0.253
# ORB%                             6.4
# DRB%                            14.1
# TRB%                            10.2
# AST%                            10.4
# STL%                             1.2
# BLK%                             1.1
# TOV%                            12.6
# USG%                            17.2
# blanl                            NaN
# OWS                              0.5
# DWS                              0.4
# WS                               0.9
# WS/48                          0.084
# blank2                           NaN
# OBPM                            -0.4
# DBPM                            -0.6
# BPM                             -1.0
# ...

# %%
merge_df.head()
# Out:
#      Year         Player Pos   Age   Tm    TS%   3PAr    FTr  ORB%  DRB%  ...  \
# 0  2017.0   Alex Abrines  SG  23.0  OKC  0.560  0.724  0.144   1.9   7.1  ...
# 2  2017.0     Quincy Acy  PF  26.0  DAL  0.355  0.412  0.176   4.6  15.2  ...
# 3  2017.0     Quincy Acy  PF  26.0  BRK  0.587  0.542  0.373   3.8  18.2  ...
# 4  2017.0   Steven Adams   C  23.0  OKC  0.589  0.002  0.392  13.0  15.5  ...
# 5  2017.0  Arron Afflalo  SG  31.0  SAC  0.559  0.360  0.221   0.7   8.4  ...
#
#      PTS           name  year_start  year_end  position  height  weight  \
# 0  406.0   Alex Abrines      2017.0    2018.0       G-F     6-6   190.0
# 2   13.0     Quincy Acy      2013.0    2018.0         F     6-7   240.0
# 3  209.0     Quincy Acy      2013.0    2018.0         F     6-7   240.0
# 4  905.0   Steven Adams      2014.0    2018.0         C     7-0   255.0
# 5  515.0  Arron Afflalo      2008.0    2018.0         G     6-5   210.0
#
#    birth_date                                college      Team
# ...

# %%
merge_df.groupby('Tm')['Player'].sum()
# Out:
#   Cell In[112], line 1
#     merge_df.groupby('Tm')['Player']).sum()
#                                     ^
# SyntaxError: unmatched ')'

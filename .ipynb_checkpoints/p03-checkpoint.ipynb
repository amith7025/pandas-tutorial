# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon.csv')
df.head(25)
# Out:
#      #                       Name  Type 1  Type 2  Total  HP  Attack  Defense  \
# 0    1                  Bulbasaur   Grass  Poison    318  45      49       49
# 1    2                    Ivysaur   Grass  Poison    405  60      62       63
# 2    3                   Venusaur   Grass  Poison    525  80      82       83
# 3    3      VenusaurMega Venusaur   Grass  Poison    625  80     100      123
# 4    4                 Charmander    Fire     NaN    309  39      52       43
# 5    5                 Charmeleon    Fire     NaN    405  58      64       58
# 6    6                  Charizard    Fire  Flying    534  78      84       78
# 7    6  CharizardMega Charizard X    Fire  Dragon    634  78     130      111
# 8    6  CharizardMega Charizard Y    Fire  Flying    634  78     104       78
# 9    7                   Squirtle   Water     NaN    314  44      48       65
# 10   8                  Wartortle   Water     NaN    405  59      63       80
# ...

# %%
df.loc[df['Attack'] >= 150].shape
# Out:
# (29, 13)

# %%
df[df['Speed'] <= 10]
# Out:
#        #       Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 230  213    Shuckle     Bug   Rock    505   20      10      230       10
# 359  328   Trapinch  Ground    NaN    290   45     100       45       45
# 486  438     Bonsly    Rock    NaN    290   50      80       95       10
# 495  446   Munchlax  Normal    NaN    390  135      85       40       40
# 658  597  Ferroseed   Grass  Steel    305   44      50       91       24
#
#      Sp. Def  Speed  Generation  Legendary
# 230      230      5           2      False
# 359       45     10           3      False
# 486       45     10           4      False
# 495       85      5           4      False
# 658       86     10           5      False

# %%
df[df['Sp. Def'] <= 25]
# Out:
#        #                Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 13    10            Caterpie      Bug     NaN    195   45      30       35
# 14    11             Metapod      Bug     NaN    205   50      20       55
# 16    13              Weedle      Bug  Poison    195   40      35       30
# 17    14              Kakuna      Bug  Poison    205   45      25       50
# 44    39          Jigglypuff   Normal   Fairy    270  115      45       20
# 97    90            Shellder    Water     NaN    305   30      65      100
# 106   98              Krabby    Water     NaN    325   30     105       90
# 125  116              Horsea    Water     NaN    295   30      40       70
# 139  129            Magikarp    Water     NaN    200   20      10       55
# 188  174           Igglybuff   Normal   Fairy    210   90      30       15
# 209  194              Wooper    Water  Ground    210   55      45       45
# ...

# %%
l = ~(df['Legendary'] == True)
l.head(25)
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# Name: Legendary, dtype: bool

# %%
(df['Legendary'] == True).sum()
# Out:
# 65

# %%
df.loc[df['Legendary'] == True].sort_values(by='Legendary')
# Out:
#        #                   Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 156  144               Articuno      Ice  Flying    580   90      85      100
# 542  485                Heatran     Fire   Steel    600   91      90      106
# 543  486              Regigigas   Normal     NaN    670  110     160      110
# 544  487  GiratinaAltered Forme    Ghost  Dragon    680  150     100      120
# 545  487   GiratinaOrigin Forme    Ghost  Dragon    680  150     120      100
# ..   ...                    ...      ...     ...    ...  ...     ...      ...
# 430  386    DeoxysDefense Forme  Psychic     NaN    600   50      70      160
# 431  386      DeoxysSpeed Forme  Psychic     NaN    600   50      95       90
# 537  480                   Uxie  Psychic     NaN    580   75      75      130
# 539  482                  Azelf  Psychic     NaN    580   75     125       70
# 799  721              Volcanion     Fire   Water    600   80     110      120
#
# ...

# %%
m = df.loc[df['Legendary'] == True]
m.head()
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 156      100       95      125     85           1       True
# 157       85      125       90    100           1       True
# 158       90      125       85     90           1       True
# 162       90      154       90    130           1       True
# 163      100      154      100    130           1       True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.loc[(df['Attack'].max())]
# Out:
# #                 176
# Name          Togetic
# Type 1          Fairy
# Type 2         Flying
# Total             405
# HP                 55
# Attack             40
# Defense            85
# Sp. Atk            80
# Sp. Def           105
# Speed              40
# Generation          2
# Legendary       False
# Name: 190, dtype: object

# %%
df.sort_values(by='Defense',ascending=False).head()
# Out:
#        #                 Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 230  213              Shuckle    Bug    Rock    505  20      10      230
# 224  208  SteelixMega Steelix  Steel  Ground    610  75     125      230
# 333  306    AggronMega Aggron  Steel     NaN    630  70     140      230
# 223  208              Steelix  Steel  Ground    510  75      85      200
# 414  377             Regirock   Rock     NaN    580  80     100      200
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 230       10      230      5           2      False
# 224       55       95     30           2      False
# 333       60       80     50           3      False
# 223       55       65     30           2      False
# 414       50      100     50           3       True

# %%
df.sort_values(by=['Defense','Attack'],ascending=[False,True])
# Out:
#        #                 Name    Type 1   Type 2  Total   HP  Attack  Defense  \
# 230  213              Shuckle       Bug     Rock    505   20      10      230
# 224  208  SteelixMega Steelix     Steel   Ground    610   75     125      230
# 333  306    AggronMega Aggron     Steel      NaN    630   70     140      230
# 223  208              Steelix     Steel   Ground    510   75      85      200
# 414  377             Regirock      Rock      NaN    580   80     100      200
# ..   ...                  ...       ...      ...    ...  ...     ...      ...
# 257  238             Smoochum       Ice  Psychic    305   45      30       15
# 186  172                Pichu  Electric      NaN    205   20      40       15
# 261  242              Blissey    Normal      NaN    540  255      10       10
# 121  113              Chansey    Normal      NaN    450  250       5        5
# 488  440              Happiny    Normal      NaN    220  100       5        5
#
# ...

# %%
df.loc[(df['Type 1'] == 'Fire') & (df['Type 2'] == 'Flying')]
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
df.loc[(df['Type 1'] == 'Poison') | (df['Type 2'] == 'Poison')].iloc[0,1]
# Out:
# 'Bulbasaur'

# %%
df.loc[df['Type 1'] == 'Ice'].sort_values(by='Defense', ascending=False)
# Out:
#        #               Name Type 1   Type 2  Total   HP  Attack  Defense  \
# 789  713            Avalugg    Ice      NaN    514   95     117      184
# 522  471            Glaceon    Ice      NaN    525   65      60      110
# 156  144           Articuno    Ice   Flying    580   90      85      100
# 415  378             Regice    Ice      NaN    580   80      50      100
# 400  365            Walrein    Ice    Water    530  110      80       90
# 645  584          Vanilluxe    Ice      NaN    535   71      95       85
# 788  712           Bergmite    Ice      NaN    304   55      69       85
# 524  473          Mamoswine    Ice   Ground    530  110     130       80
# 396  362             Glalie    Ice      NaN    480   80      80       80
# 397  362  GlalieMega Glalie    Ice      NaN    580   80     120       80
# 239  221          Piloswine    Ice   Ground    450  100     100       80
# 675  614            Beartic    Ice      NaN    485   95     110       80
# ...

# %%
value1 = df.loc[df['Legendary'],'Type 1'].value_counts()
value2 = df.loc[df['Legendary'],'Type 2'].value_counts()
result = pd.concat([value1, value2], axis=1)
result
# Out:
# (          count  count
#  Psychic    14.0    5.0
#  Dragon     12.0    4.0
#  Fire        5.0    3.0
#  Electric    4.0    1.0
#  Water       4.0    1.0
#  Rock        4.0    NaN
#  Steel       4.0    1.0
#  Ground      4.0    1.0
#  Grass       3.0    NaN
#  Ice         2.0    3.0
#  Normal      2.0    NaN
#  Ghost       2.0    1.0
#  Dark        2.0    1.0
#  Flying      2.0   13.0
#  Fairy       1.0    2.0
#  Fighting    NaN    4.0,
#  Type 1
#  Psychic     14
#  Dragon      12
#  Fire         5
#  Electric     4
#  Water        4
#  Rock         4
#  Steel        4
#  Ground       4
#  Grass        3
#  Ice          2
#  Normal       2
#  Ghost        2
#  Dark         2
#  Flying       2
#  Fairy        1
#  Name: count, dtype: int64)

# %%
df.query("`Type 1` == 'Fire' and `Type 2` =='Flying'")
# Out:
#        #                       Name Type 1  Type 2  Total   HP  Attack  \
# 6      6                  Charizard   Fire  Flying    534   78      84
# 8      6  CharizardMega Charizard Y   Fire  Flying    634   78     104
# 158  146                    Moltres   Fire  Flying    580   90     100
# 270  250                      Ho-oh   Fire  Flying    680  106     130
# 730  662                Fletchinder   Fire  Flying    382   62      73
# 731  663                 Talonflame   Fire  Flying    499   78      81
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6         78      109       85    100           1      False
# 8         78      159      115    100           1      False
# 158       90      125       85     90           1       True
# 270       90      110      154     90           2       True
# 730       55       56       52     84           6      False
# 731       71       74       69    126           6      False

# %%
import pandas as pd
import missingno as msno

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df['bathroom'] = df['bathrooms'].astype(int)

# %%
del df['bathroom']

# %%
df.loc[((df['bathrooms'] >=2 ) | (df['bathrooms'] < 2.5))].value_counts()
# Out:
# id          date        price     bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode  lat      long      sqft_living15  sqft_lot15
# 1000102     2014-09-16  280000.0  6         3.0        2400         9373      2.0     0           0     3          7      2400        0              1991      0             98002    47.3262  -122.214  2060           7316          1
# 6324000090  2015-05-11  210000.0  2         1.0        990          8140      1.0     0           0     1          6      990         0              1910      0             98116    47.5828  -122.382  2150           5000          1
# 6329000380  2014-06-19  319950.0  2         1.0        920          8341      1.0     0           0     3          7      920         0              1939      0             98146    47.5015  -122.380  2330           9792          1
# 6329000190  2014-07-29  750000.0  4         2.0        2520         21834     1.0     1           4     3          8      1420        1100           1960      0             98146    47.4996  -122.378  1700           8100          1
# 6329000185  2015-03-29  540000.0  3         3.0        2600         23361     1.5     1           4     3          8      2150        450            1912      0             98146    47.4997  -122.379  1700           14700         1
#                                                                                                                                                                                                                                      ..
# 2767603649  2014-07-30  520000.0  3         2.0        1210         1250      3.0     0           0     3          8      1210        0              2014      0             98107    47.6722  -122.384  1780           5000          1
# 2767603615  2014-09-03  481000.0  2         2.0        1290         1137      3.0     0           0     3          8      1290        0              2007      0             98107    47.6718  -122.382  1290           1332          1
# 2767603612  2015-01-13  489000.0  2         2.0        1290         1334      3.0     0           0     3          8      1290        0              2007      0             98107    47.6719  -122.382  1350           1334          1
#             2014-05-12  500000.0  2         2.0        1290         1334      3.0     0           0     3          8      1290        0              2007      0             98107    47.6719  -122.382  1350           1334          1
# 9900000190  2014-10-30  268950.0  3         1.0        1320         8100      1.0     0           0     3          6      880         440            1943      0             98166    47.4697  -122.351  1000           8100          1
# Name: count, Length: 21613, dtype: int64

# %%
df.loc[(df['bathrooms'] == 2.25,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 4.5,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 1.5,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 2.5,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 1.75,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 2.75,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 3.25,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 3.5,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 0.75,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 4.75,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 4.25,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 3.75,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 1.25,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 5.25,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 0.5,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 5.5,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 6.75,'bathrooms')] = 7

# %%
df.loc[(df['bathrooms'] == 5.75,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 7.5,'bathrooms')] = 8

# %%
df.loc[(df['bathrooms'] == 7.75,'bathrooms')] = 8

# %%
df.loc[(df['bathrooms'] == 6.25,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 6.5,'bathrooms')] = 7

# %%
df['bathrooms']
# Out:
# 0        1.0
# 1        2.0
# 2        1.0
# 3        3.0
# 4        2.0
#         ...
# 21608    3.0
# 21609    3.0
# 21610    1.0
# 21611    3.0
# 21612    1.0
# Name: bathrooms, Length: 21613, dtype: float64

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3        1.0         1180
# 1  6414100192 2014-12-09  538000.0         3        2.0         2570
# 2  5631500400 2015-02-25  180000.0         2        1.0          770
# 3  2487200875 2014-12-09  604000.0         4        3.0         1960
# 4  1954400510 2015-02-18  510000.0         3        2.0         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
df.loc[df['bedrooms'] == 33]
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 15870  2402100895 2014-06-25  640000.0        33        2.0         1620
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 15870      6000     1.0           0     0  ...      7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 15870            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 15870           1330        4700
#
# [1 rows x 21 columns]

# %%
df.loc[df['bathrooms'] == 8]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 7252   6762700020 2014-10-13  7700000.0         6        8.0        12050
# 8546    424049043 2014-08-11   450000.0         9        8.0         4050
# 9254   9208900037 2014-09-19  6885000.0         6        8.0         9890
# 12777  1225069038 2014-05-05  2280000.0         7        8.0        13540
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 7252      27600     2.5           0     3  ...     13        8570
# 8546       6504     2.0           0     0  ...      7        4050
# 9254      31374     2.0           0     4  ...     13        8860
# 12777    307752     3.0           0     4  ...     12        9410
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 7252            3480      1910          1987    98102  47.6298 -122.323
# 8546               0      1996             0    98144  47.5923 -122.301
# 9254            1030      2001             0    98039  47.6305 -122.240
# 12777           4130      1999             0    98053  47.6675 -121.986
#
#        sqft_living15  sqft_lot15
# 7252            3940        8800
# 8546            1448        3866
# 9254            4540       42730
# 12777           4850      217800
#
# [4 rows x 21 columns]

# %%
df.head(1).T
# Out:
#                                  0
# id                      7129300520
# date           2014-10-13 00:00:00
# price                     221900.0
# bedrooms                         3
# bathrooms                      1.0
# sqft_living                   1180
# sqft_lot                      5650
# floors                         1.0
# waterfront                       0
# view                             0
# condition                        3
# grade                            7
# sqft_above                    1180
# sqft_basement                    0
# yr_built                      1955
# yr_renovated                     0
# zipcode                      98178
# lat                        47.5112
# long                      -122.257
# sqft_living15                 1340
# sqft_lot15                    5650

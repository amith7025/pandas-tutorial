# %%
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3          2         1180      5650     1.0
# 1  6414100192  538000.0         3          2         2570      7242     2.0
# 2  5631500400  180000.0         2          2          770     10000     1.0
# 3  2487200875  604000.0         4          2         1960      5000     1.0
# 4  1954400510  510000.0         3          2         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
msno.bar(df)
# Out:
# <Axes: >

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df['bathrooms'].unique()
# Out:
# array([1.  , 2.25, 3.  , 2.  , 4.5 , 1.5 , 2.5 , 1.75, 2.75, 3.25, 4.  ,
#        3.5 , 0.75, 4.75, 5.  , 4.25, 3.75, 0.  , 1.25, 5.25, 6.  , 0.5 ,
#        5.5 , 6.75, 5.75, 8.  , 7.5 , 7.75, 6.25, 6.5 ])

# %%
df['bathroom'] = df['bathrooms'].astype(int)

# %%
del df['bathroom']

# %%
df.loc[((df['bathrooms'] >=2 ) | (df['bathrooms'] < 2.5)),'bathrooms'] = 2

# %%
df.loc[(df['bathrooms'] == 2.25,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 4.5,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 1.5,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 2.5,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 1.75,'bathrooms')] = 2

# %%
df.loc[(df['bathrooms'] == 2.75,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 3.25,'bathrooms')] = 3

# %%
df.loc[(df['bathrooms'] == 3.5,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 0.75,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 4.75,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 4.25,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 3.75,'bathrooms')] = 4

# %%
df.loc[(df['bathrooms'] == 1.25,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 5.25,'bathrooms')] = 5

# %%
df.loc[(df['bathrooms'] == 0.5,'bathrooms')] = 1

# %%
df.loc[(df['bathrooms'] == 5.5,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 6.75,'bathrooms')] = 7

# %%
df.loc[(df['bathrooms'] == 5.75,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 7.5,'bathrooms')] = 8

# %%
df.loc[(df['bathrooms'] == 7.75,'bathrooms')] = 8

# %%
df.loc[(df['bathrooms'] == 6.25,'bathrooms')] = 6

# %%
df.loc[(df['bathrooms'] == 6.5,'bathrooms')] = 7

# %%
df['bathrooms'] = df['bathrooms'].astype(int)

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3          2         1180      5650     1.0
# 1  6414100192  538000.0         3          2         2570      7242     2.0
# 2  5631500400  180000.0         2          2          770     10000     1.0
# 3  2487200875  604000.0         4          2         1960      5000     1.0
# 4  1954400510  510000.0         3          2         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33], dtype=int64)

# %%
df.loc[df['bedrooms'] == 33].T
# Out:
#                              15870
# id                      2402100895
# date           2014-06-25 00:00:00
# price                     640000.0
# bedrooms                        33
# bathrooms                      2.0
# sqft_living                   1620
# sqft_lot                      6000
# floors                         1.0
# waterfront                       0
# view                             0
# condition                        5
# grade                            7
# sqft_above                    1040
# sqft_basement                  580
# yr_built                      1947
# yr_renovated                     0
# zipcode                      98103
# lat                        47.6878
# long                      -122.331
# sqft_living15                 1330
# sqft_lot15                    4700

# %%
df.loc[df['bathrooms'] == 8]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.head(1).T
# Out:
#                                  0
# id                      7129300520
# price                     221900.0
# bedrooms                         3
# bathrooms                        2
# sqft_living                   1180
# sqft_lot                      5650
# floors                         1.0
# waterfront                       0
# view                             0
# condition                        3
# grade                            7
# sqft_above                    1180
# sqft_basement                    0
# yr_built                      1955
# yr_renovated                     0
# zipcode                      98178
# lat                        47.5112
# long                      -122.257
# sqft_living15                 1340
# sqft_lot15                    5650
# date_only      2014-10-13 00:00:00

# %%
df.iloc[12777]
# Out:
# id                        1225069038
# price                      2280000.0
# bedrooms                           7
# bathrooms                          2
# sqft_living                    13540
# sqft_lot                      307752
# floors                           3.0
# waterfront                         0
# view                               4
# condition                          3
# grade                             12
# sqft_above                      9410
# sqft_basement                   4130
# yr_built                        1999
# yr_renovated                       0
# zipcode                        98053
# lat                          47.6675
# long                        -121.986
# sqft_living15                   4850
# sqft_lot15                    217800
# date_only        2014-05-05 00:00:00
# Name: 12777, dtype: object

# %%
df['date_only'] = df['date'].dt.date
del df['date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Envs\workshop\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\Envs\workshop\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Envs\workshop\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3          2         1180      5650     1.0
# 1  6414100192  538000.0         3          2         2570      7242     2.0
# 2  5631500400  180000.0         2          2          770     10000     1.0
# 3  2487200875  604000.0         4          2         1960      5000     1.0
# 4  1954400510  510000.0         3          2         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df['bedrooms'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='bedrooms'>

# %%
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3          2         1180      5650     1.0
# 1  6414100192  538000.0         3          2         2570      7242     2.0
# 2  5631500400  180000.0         2          2          770     10000     1.0
# 3  2487200875  604000.0         4          2         1960      5000     1.0
# 4  1954400510  510000.0         3          2         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  int32
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
df['date_only'] = pd.to_datetime(df['date_only'])

# %%
df['bathrooms'] = df['bathrooms'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  int64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286        NaN    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350        NaN     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000        NaN     0.576671  0.031703
# bathrooms           NaN       NaN       NaN        NaN          NaN       NaN
# sqft_living   -0.012258  0.702035  0.576671        NaN     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703        NaN     0.172826  1.000000
# floors         0.018525  0.256794  0.175429        NaN     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582        NaN     0.103818  0.021604
# view           0.011592  0.397293  0.079532        NaN     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472        NaN    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967        NaN     0.762704  0.113621
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True)
# Out:
# <Axes: >

# %%
plt.plot(df['id'][:10],df['price'][:10])

# %%
df['bathrooms'].unique()
# Out:
# array([2], dtype=int64)

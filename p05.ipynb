# %%
import pandas as pd

# %%
df = pd.read_csv('athletes.csv',date_format=('%Y-%m-%d'),parse_dates=['dob'])
df.head(100)
# Out:
#            id                    name nationality     sex       dob  height  \
# 0   736041664          A Jesus Garcia         ESP    male  10/17/69    1.72
# 1   532037425              A Lam Shin         KOR  female   9/23/86    1.68
# 2   435962603             Aaron Brown         CAN    male   5/27/92    1.98
# 3   521041435              Aaron Cook         MDA    male    1/2/91    1.83
# 4    33922579              Aaron Gate         NZL    male  11/26/90    1.81
# ..        ...                     ...         ...     ...       ...     ...
# 95   46940649        Adas Juskevicius         LTU    male    1/3/89    1.94
# 96  512592841            Adel Gholami         IRI    male    2/9/86    1.95
# 97  302277635            Adel Mechaal         ESP    male   12/5/90    1.82
# 98  216864827  Adel Mojallalimoghadam         IRI    male   3/21/93    1.85
# 99  153013732             Adela Bruns         CZE  female    2/5/87    1.71
#
#     weight       sport  gold  silver  bronze
# ...

# %%
df['dob'] = pd.to_datetime(df['dob'],format='%Y-%m-%d')
# Out:
# C:\Users\amith\AppData\Local\Temp\ipykernel_12100\1262302991.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['dob'] = pd.to_datetime(df['dob'])

# %%
type(df.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df.iloc[1]
# Out:
# id              532037425
# name           A Lam Shin
# nationality           KOR
# sex                female
# dob               9/23/86
# height               1.68
# weight               56.0
# sport             fencing
# gold                    0
# silver                  0
# bronze                  0
# Name: 1, dtype: object

# %%
df.loc['11/26/90']
# Out:
#                 id           name nationality   sex  height  weight    sport  \
# dob
# 11/26/90  33922579     Aaron Gate         NZL  male    1.81    71.0  cycling
# 11/26/90  99018195  Isak Ohrstrom         SWE  male    1.77    72.0    canoe
#
#           gold  silver  bronze
# dob
# 11/26/90     0       0       0
# 11/26/90     0       0       0

# %%
df.loc[df['gold'] > 1]
# Out:
#                  id                name nationality     sex  height  weight  \
# dob
# 10/22/95  840071617          Aisen Chen         CHN    male    1.68    60.0
# 11/18/85  629649792       Allyson Felix         USA  female    1.68    56.0
# 5/26/81   261223419       Anthony Ervin         USA    male    1.91    80.0
# 1/31/93   841861773          Bonchan Ku         KOR    male    1.81    84.0
# 8/16/96   247346852      Caeleb Dressel         USA    male    1.91    86.0
# 1/11/87   552666305        Danuta Kozak         HUN  female    1.68    63.0
# 6/28/92   715359899     Elaine Thompson         JAM  female    1.67    57.0
# 8/14/86    99788705     Gabriella Szabo         HUN  female    1.70    62.0
# 5/13/87   887795017        Hyejin Chang         KOR  female    1.58    50.0
# 3/23/88   441111357         Jason Kenny         GBR    male    1.78    81.0
# 3/17/97   960103057       Katie Ledecky         USA  female    1.83    72.0
# ...

# %%
import math

# %%
def NCR(n):
    f = math.factorial()
    return f(n)/(f(2))
